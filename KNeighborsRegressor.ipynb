# %% [markdown]
# <a href="https://colab.research.google.com/github/HassanAbdulJabbar/Diabetes-prediction/blob/main/KNeighborsRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # kNN as a Regression Algorithm

# %%
import inspect
import matplotlib.pyplot as plt
inspect.getsource(plt)
# Out:
# '# Note: The first part of this file can be modified in place, but the latter\n# part is autogenerated by the boilerplate.py script.\n\n"""\n`matplotlib.pyplot` is a state-based interface to matplotlib. It provides\na MATLAB-like way of plotting.\n\npyplot is mainly intended for interactive plots and simple cases of\nprogrammatic plot generation::\n\n    import numpy as np\n    import matplotlib.pyplot as plt\n\n    x = np.arange(0, 5, 0.1)\n    y = np.sin(x)\n    plt.plot(x, y)\n\nThe object-oriented API is recommended for more complex plots.\n"""\n\nimport functools\nimport importlib\nimport inspect\nimport logging\nfrom numbers import Number\nimport re\nimport sys\nimport time\n\nfrom cycler import cycler\nimport matplotlib\nimport matplotlib.colorbar\nimport matplotlib.image\nfrom matplotlib import rcsetup, style\nfrom matplotlib import _pylab_helpers, interactive\nfrom matplotlib import cbook\nfrom matplotlib.cbook import dedent, deprecated, silent_list, warn_deprecated\nfrom ma
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn import datasets
df = datasets.load_diabetes()
dataframe = pd.DataFrame(df.data, columns = df.feature_names)

# %%
dataframe.head()
# Out:
#         age       sex       bmi  ...        s4        s5        s6
# 0  0.038076  0.050680  0.061696  ... -0.002592  0.019908 -0.017646
# 1 -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068330 -0.092204
# 2  0.085299  0.050680  0.044451  ... -0.002592  0.002864 -0.025930
# 3 -0.089063 -0.044642 -0.011595  ...  0.034309  0.022692 -0.009362
# 4  0.005383 -0.044642 -0.036385  ... -0.002592 -0.031991 -0.046641
#
# [5 rows x 10 columns]

# %%
headernames = ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
dataframe.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
dataframe.describe()
# Out:
#                 age           sex  ...            s5            s6
# count  4.420000e+02  4.420000e+02  ...  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16  ... -3.830854e-16 -3.412882e-16
# std    4.761905e-02  4.761905e-02  ...  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02  ... -1.260974e-01 -1.377672e-01
# 25%   -3.729927e-02 -4.464164e-02  ... -3.324879e-02 -3.317903e-02
# 50%    5.383060e-03 -4.464164e-02  ... -1.947634e-03 -1.077698e-03
# 75%    3.807591e-02  5.068012e-02  ...  3.243323e-02  2.791705e-02
# max    1.107267e-01  5.068012e-02  ...  1.335990e-01  1.356118e-01
#
# [8 rows x 10 columns]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
correlation_matrix = dataframe.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)

# %%
from sklearn.model_selection import train_test_split
X_ = dataframe.bmi #independent variable
y_ = dataframe.bp #dependent variable


X_ = np.array(X_).reshape(-1,1)
y_ = np.array(y_).reshape(-1,1)

print(X_.shape)
print(y_.shape)
X_train, X_test, Y_train, Y_test = train_test_split(X_, y_, test_size = 0.2, random_state=5)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
from sklearn.neighbors import KNeighborsRegressor
reg_1 = KNeighborsRegressor(n_neighbors = 1)
reg_1.fit(X_train, Y_train)
# Out:
# (442, 1)
# (442, 1)
# (353, 1)
# (89, 1)
# (353, 1)
# (89, 1)
# KNeighborsRegressor(n_neighbors=1)

# %%
from sklearn.metrics import mean_squared_error
y_train_predict_1 = reg_1.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict_1)))
r2 = round(reg_1.score(X_train, Y_train),2)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.04872152604834715
# R2 score is -0.01

# %%
# model evaluation for test set

y_pred_1 = reg_1.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_pred_1)))
r2 = round(reg_1.score(X_test, Y_test),2)

print("The model performance for training set")
print("--------------------------------------")
print("Root Mean Squared Error: {}".format(rmse))
print("R^2: {}".format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# Root Mean Squared Error: 0.0635857652917852
# R^2: -1.09

# %% [markdown]
# # kNN as a Regression Algorithm
#
# ### Modify the existing code that you did for Linear Regression Model.
# #### Step 1. Load the target dataset
# #### Step 2. Perform Preprocessing
# #### Step 3. Visualize the correlations and select dependent and independent features
# #### Step 4. import the kNN regressor from sklearn and fit this model.
# #### Step 5. Evaluate on the basis of MSE and R2.
